# %%
import sys
sys.path.append('C:\Dropbox\PycharmProjects\geothermal_power_potential')

# %%
import gppeval

nj = gppeval.GeothermalPowerPlant()
tools = gppeval.Tools()
sim = gppeval.MonteCarloSimulation()

# %%
nj = tools.read_file_csv('NombreJesusElSalvador_11Aug2016_001.csv')
# Out:
# READ FILE ... OK

# %%
print nj
# Out:
# +--------------------------------------------------------+----------+----------+
# |                          name                          | lat [oC] | lon [oC] |
# +--------------------------------------------------------+----------+----------+
# |             Nombre de Jesus. Chalatenango              |  14.001  | -88.737  |
# +--------------------------------------------------------+----------+----------+
# +======+===============================+========+===========+======+===============+=====+======+======+=====+
# | Item |           Variable            | Symbol |   Units   | Min  |  Most_Likely  | Max | Mean |  SD  | PDF |
# +======+===============================+========+===========+======+===============+=====+======+======+=====+
# |  0   |             area              |   A    |    km2    |  5   |       6       |  7  |  0   |  0   |  T  |
# +------+-------------------------------+--------+-----------+------+---------------+-----+------+------+-----+
# ...

# %%
nj = sim.calc_energy_potential(nj)
tools.plot_pdf(nj, show=True)

# %%
tools.print_results(nj)
# Out:
# MAIN INFORMATION:
# Most Likely PowerGeneration [MWe]= 19.7537
# Probability of  19.7537 [MWe]= 0.6163
# P10% [MWe]= 16.126
#
# STATISTICAL ANALYSIS:
# Iterations= 10000
# Mean= 21.5109 [MWe]
# Median= 21.0176 [MWe]
# Standard Deviation= 4.52226 [MWe]
# Skew= 0.54311
# Kurt= 3.20339
# Minimum= 9.74076 [MWe]
# Maximum= 40.3904 [MWe]
# P5%= 14.9141 [MWe]
# P10%= 16.126 [MWe]
# P15%= 16.9481 [MWe]
# P20%= 17.6228 [MWe]
# P25%= 18.2348 [MWe]
# P30%= 18.8036 [MWe]
# P35%= 19.3888 [MWe]
# P40%= 19.9237 [MWe]
# P45%= 20.4643 [MWe]
# P50%= 21.0176 [MWe]
# P55%= 21.5837 [MWe]
# P60%= 22.1873 [MWe]
# P65%= 22.8655 [MWe]
# P70%= 23.5628 [MWe]
# P75%= 24.3669 [MWe]
# P80%= 25.1562 [MWe]
# P85%= 26.2455 [MWe]
# P90%= 27.6094 [MWe]
# P95%= 29.8893 [MWe]
#
# END
