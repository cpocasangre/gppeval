# %% [markdown]
# # use onsen library

# %%
import onsen as hp

gpp1 = hp.GeothermalPowerPlant()
tools = hp.Tools()
sim = hp.MonteCarloSimulation()

# in case change, restart python Kernel
# mode = 'Qt4Agg'
mode = 'notebook'
# mode = 'inline'
if mode is 'Qt4Agg':
    tools.set_backend_figure()
elif mode is 'notebook':
     # %matplotlib nbagg   
else:
    pass

# %% [markdown]
# # 1) data from file

# %%
gpp1 = tools.read_file_csv(fn_input='HishikariKagoshima_06Nov2017_001.csv')
#print gpp1
# Out:
# READ FILE ... OK

# %% [raw]
# # runnning the simulation

# %%
sim.set_iterations(1000)
gpp1=sim.calc_energy_potential(gpp1)

# %% [raw]
# # show results

# %%
# setting variables
tools.set_eng_format('k') # 'k' kilo
tools.set_num_figures_plot(4)
# tools.print_results(gpp1)
# tools.plot_pdf(gpp1, x_lim=[100,3500])
# tools.plot_pdf(gpp1, -1, x_lim=[0,3500])
tools.plot_pdf(gpp1, type_graph='higher', show=True)
# tools.plot_pdf(gpp1, 'linear')
# tools.show_pdf()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 2) data from notebook

# %%
gpp1.set_name('Nombre de Jesus. El Salvador')
gpp1.set_location(lat=14, lon=-88.73)
gpp1.set_area(min=5, most_likely=6, max=7, mean=0.0, sd=0.0, pdf='T', doc=5)
gpp1.set_thickness(min=450, most_likely=500, max=600, mean=0.0, sd=0.0, pdf='T')
gpp1.set_reservoir_temp(min=130, most_likely=160, max=163, mean=0.0, sd=0.0, pdf='T')
gpp1.set_abandon_temp(min=0.0, most_likely=80, max=0.0, mean=0.0, sd=0.0, pdf='C')
gpp1.set_porosity(min=0.0, most_likely=0.06, max=0.0, mean=0.06, sd=0.02, pdf='L')
gpp1.set_rock_specific_heat(min=0.85, most_likely=0.85, max=0.9, mean=0.0, sd=0.0, pdf='T')
gpp1.set_fluid_specific_heat(min=0, most_likely=5.18, max=0, mean=0.0, sd=0.0, pdf='C')
gpp1.set_rock_density(min=0, most_likely=2500, max=0, mean=0.0, sd=0.0, pdf='C')
gpp1.set_fluid_density(min=0, most_likely=764.45, max=0, mean=0.0, sd=0.0, pdf='C')
gpp1.set_recovery_factor(min=0.0, most_likely=0.23, max=0.0, mean=0.0, sd=0.0, pdf='C')
gpp1.set_conversion_efficiency(min=0.1, most_likely=0.12, max=0.2, mean=0.0, sd=0.0, pdf='T')
gpp1.set_plant_net_capacity_factor(min=0.9, most_likely=0.95, max=1.0, mean=0.0, sd=0.0, pdf='T')
gpp1.set_lifespan(min=0, most_likely=25, max=0, mean=0.0, sd=0.0, pdf='C')

# %%
# runnning the simulation

# %%
sim.set_iterations(1000)
gpp1=sim.calc_energy_potential(gpp1)

# %%
# show results

# %%
# setting variables
tools.set_eng_format('M') # 'k' kilo
tools.set_num_figures_plot(3)

tools.print_results(gpp1)
tools.plot_pdf(gpp1, type_graph='hist')
tools.plot_pdf(gpp1, type_graph='lower')
tools.plot_pdf(gpp1, type_graph='higher')
tools.plot_pdf(gpp1, type_graph='linear')
tools.show_pdf()
# Out:
# MAIN INFORMATION:
# Most Likely PowerGeneration [MWe]= 19.7537
# Probability of  19.7537 [MWe]= 0.618
# P10% [MWe]= 16.2883
#
# STATISTICAL ANALYSIS:
# Iterations= 1000
# Mean= 21.4683 [MWe]
# Median= 21.0479 [MWe]
# Standard Deviation= 4.42181 [MWe]
# Skew= 0.442585
# Kurt= 2.85784
# Minimum= 11.3725 [MWe]
# Maximum= 37.3533 [MWe]
# P5%= 14.8924 [MWe]
# P10%= 16.2883 [MWe]
# P15%= 16.9636 [MWe]
# P20%= 17.5627 [MWe]
# P25%= 18.1454 [MWe]
# P30%= 18.8063 [MWe]
# P35%= 19.2986 [MWe]
# P40%= 20.0407 [MWe]
# P45%= 20.5557 [MWe]
# P50%= 21.0479 [MWe]
# P55%= 21.6272 [MWe]
# P60%= 22.1533 [MWe]
# P65%= 22.7547 [MWe]
# P70%= 23.4565 [MWe]
# P75%= 24.4974 [MWe]
# P80%= 25.1969 [MWe]
# P85%= 26.154 [MWe]
# P90%= 27.7348 [MWe]
# P95%= 29.6468 [MWe]
#
# END
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="916">
