# %%
import sys
sys.path.append('C:\Dropbox\PycharmProjects\geothermal_power_potential')

# %%
import gppeval

# sv_reservoir = gppeval.GeothermalPowerPlant()
tools = gppeval.Tools()
sim = gppeval.MonteCarloSimulation()

# %%
sv_reservoir = tools.read_file_csv('SanVicenteElSalvador_08Jun2016_001.csv')
# sv_reservoir.set_porosity(pdf='N')
sv_reservoir = sim.calc_energy_potential(sv_reservoir)
tools.plot_pdf(sv_reservoir, show=True)
# Out:
# READ FILE ... OK

# %%
# tools.plot_pdf(sv_reservoir, show=True)/

# %%
# print sv_reservoir

# %%
tools.write_file_cvs(sv_reservoir)
# Out:
# WRITE TO FILE ... OK

# %%
# import mcerp
import pylab

# %%
sv_reservoir.set_porosity(mean=5.149, sd=0.737)

# %%
phi = sim.probability_distribution_function(sv_reservoir.porosity)

# %%
phi
# Out:
# uv(225.950366973, 36498.1231118, 2.96577952896, 19.3831524676)

# %%
phi.plot()
pylab.xlim(xmax=500, xmin=0)
pylab.show()

# %%
print phi.percentile(0.05)
# Out:
# 51.2668377076
